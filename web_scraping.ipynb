# %% [markdown]
# # 1. Data Collection & Web Scraping

# %% [markdown]
# ### Getting list of all US resorts from skiresorts.info

# %%
import requests
from bs4 import BeautifulSoup

resorts = []

# Gets a specified number of resorts from the skiresort.info resort list
def get_resorts_from_url(url, length):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    i = 0 # Index for only getting first n results
    temp_resorts = []

    # Find all a tags with class 'h3' and href containing 'ski-resort'
    for a in soup.find_all('a', class_='h3'):
        href = a.get('href')
        if href and 'ski-resort' in href:
            name = a.text.strip()
            temp_resorts.append({'name': name, 'url': href})
        
        i += 1
        if i >= length:
            break

    return temp_resorts

resorts.extend(get_resorts_from_url("https://www.skiresort.info/ski-resorts/usa/", 50))
resorts.extend(get_resorts_from_url("https://www.skiresort.info/ski-resorts/usa/page/2/", 200))
resorts.extend(get_resorts_from_url("https://www.skiresort.info/ski-resorts/usa/page/3/", 200))
resorts.extend(get_resorts_from_url("https://www.skiresort.info/ski-resorts/usa/page/5/", 81))

print(f"Total resorts extracted: {len(resorts)}")
# Out:
# Total resorts extracted: 531

# %% [markdown]
# ### Getting resort info from skiresort.info
#  - price, elevation, vertical distance, total trail length, number of chairlifts, location

# %%
import re
import time

us_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 
             'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 
             'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 
             'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 
             'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 
             'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
             'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 
             'Wisconsin', 'Wyoming']
i = 1 # Index used for displaying progress of code

for resort in resorts:
    try:
        response = requests.get(resort['url'], timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Price info
        price_tag = soup.find('td', id='selTicketA')

        if price_tag:
            price_text = price_tag.text.strip()
            
            # Clean and convert the price to a float or int
            match = re.search(r'\d+[.,]?\d*', price_text.replace(',', '.'))
            
            if match:
                resort['price'] = float(match.group())
            else:
                resort['price'] = None
                print(f"Price not found in format for {resort['name']}: {price_text}")
        else:
            resort['price'] = None
            print(f"Price tag not found for {resort['name']}.")

        # Elevation info
        elevation_tag = soup.find('div', id='selAlti')
        if elevation_tag:
            text = elevation_tag.get_text(strip=True)

            # Extract all numbers from the string
            numbers = re.findall(r'[\d,]+', text)
            numbers = [int(n.replace(',', '')) for n in numbers]

            if len(numbers) >= 3:
                resort['base_elevation_m'] = numbers[0]
                resort['peak_elevation_m'] = numbers[1]
                resort['vertical_drop_m'] = numbers[2]
            else:
                resort['base_elevation_m'] = resort['peak_elevation_m'] = resort['vertical_drop_m'] = None
        else:
            resort['base_elevation_m'] = resort['peak_elevation_m'] = resort['vertical_drop_m'] = None
            print(f"No elevation info found for {resort['name']}")
            
        # Slope length
        slope_tag = soup.find('strong', id='selSlopetot')
        if slope_tag:
            match = re.search(r'[\d,.]+', slope_tag.text)
            resort['slope_km'] = float(match.group().replace(',', '')) if match else None
        else:
            resort['slope_km'] = None
            print(f"No slope length info found for {resort['name']}")

        # Location
        resort['state'] = None
        paragraph = soup.find(string=lambda text: text and "is located" in text)
        if paragraph:
            parent = paragraph.find_parent()
            if parent:
                links = parent.find_all("a")

                for link in links:
                    location = link.get_text()
                    for s in us_states:
                        if s in location:
                            resort['state'] = s
                            break
        else:
            print(f"No location info found for {resort['name']}")

        # Chairlift count
        lift_tag = soup.find('strong', id='selLiftstot')
        
        if lift_tag:
            # Extract digits from the text
            lift_text = lift_tag.text.strip()
            match = re.search(r'\d+', lift_text)
            if match:
                num_lifts = int(match.group())
                resort['num_lifts'] = num_lifts
        else:
            print(f"No lift info found for {resort['name']}")

        print(f"{i} / {len(resorts)} complete: {resort['name']}")
        i += 1
        # Print info after it's all extracted
        #print(f"{resort['name']}: state = {resort['state']}, price = {resort['price']}, lifts = {resort['num_lifts']}, slope = {resort['slope_km']} km, vertical = {resort['vertical_drop_m']} m")

        time.sleep(0.25) # Don't overload the API with requests

    except Exception as e:
        print(f"Error processing {resort['name']}: {e}")
        resort['slope_km'] = resort['base_elevation_m'] = resort['peak_elevation_m'] = resort['vertical_drop_m'] = None
# Out:
# 1 / 531 complete: Big Sky Resort
# 2 / 531 complete: Vail
# 3 / 531 complete: Telluride
# 4 / 531 complete: Snowmass
# 5 / 531 complete: Mammoth Mountain
# 6 / 531 complete: Park City
# 7 / 531 complete: Deer Valley
# 8 / 531 complete: Beaver Creek
# 9 / 531 complete: Palisades Tahoe
# 10 / 531 complete: Breckenridge
# 11 / 531 complete: Keystone
# 12 / 531 complete: Sunday River
# 13 / 531 complete: Killington
# 14 / 531 complete: Winter Park Resort
# 15 / 531 complete: Bald Mountain – Sun Valley
# 16 / 531 complete: Heavenly
# 17 / 531 complete: Grand Targhee
# 18 / 531 complete: Snowbird
# 19 / 531 complete: Snowbasin
# 20 / 531 complete: Steamboat
# 21 / 531 complete: Alta
# 22 / 531 complete: Stowe
# 23 / 531 complete: Aspen Highlands
# 24 / 531 complete: Solitude
# 25 / 531 complete: Brighton
# 26 / 531 complete: Dollar Mountain – Sun Valley
# 27 / 531 complete: Copper Mountain
# 28 / 531 complete: Jackson Hole
# 29 / 531 complete: Crested Butte
# 30 / 531 complete: Buttermilk Mountain
# 31 / 531 complete: Mt. Bachelor
# 32 / 531 complete: Whiteface – Lake Placid
# Price tag not found for Yellowstone Club.
# 33 / 531 complete: Yellowstone Club
# 34 / 531 complete: Northstar California Resort
# 35 / 531 complete: Stratton
# 36 / 531 complete: June Mountain
# 37 / 531 complete: Arapahoe Basin
# 38 / 531 complete: Mt. Hood Meadows
# 39 / 531 complete: Taos
# 40 / 531 complete: Snow King Mountain – Jackson
# 41 / 531 complete: Aspen Mountain
# 42 / 531 complete: Whitefish Mountain Resort
# 43 / 531 complete: Sugarbush
# 44 / 531 complete: Sugarloaf
# 45 / 531 complete: Angel Fire
# 46 / 531 complete: Homewood Mountain Resort
# 47 / 531 complete: Sierra at Tahoe
# 48 / 531 complete: Wolf Creek
# 49 / 531 complete: Purgatory – Durango
# 50 / 531 complete: Bolton Valley
# 51 / 531 complete: Sugar Bowl
# 52 / 531 complete: Schweitzer Mountain Resort
# 53 / 531 complete: Jay Peak
# 54 / 531 complete: Okemo
# 55 / 531 complete: Mount Snow
# 56 / 531 complete: Red Lodge Mountain
# 57 / 531 complete: Bear Valley
# 58 / 531 complete: Powder Mountain
# 59 / 531 complete: Bretton Woods
# 60 / 531 complete: Mt. Rose
# 61 / 531 complete: 49 Degrees North Mountain Resort
# 62 / 531 complete: Smugglers' Notch
# Price tag not found for Infinity Slopes – Loveland (dry slopes).
# 513 / 531 complete: Infinity Slopes – Loveland (dry slopes)
# Price tag not found for Snöbahn – Centennial.
# 514 / 531 complete: Snöbahn – Centennial
# Price tag not found for Jerry's Heliski Alaska.
# No elevation info found for Jerry's Heliski Alaska
# No slope length info found for Jerry's Heliski Alaska
# No location info found for Jerry's Heliski Alaska
# No lift info found for Jerry's Heliski Alaska
# 515 / 531 complete: Jerry's Heliski Alaska
# Price tag not found for Powderbird.
# No elevation info found for Powderbird
# No slope length info found for Powderbird
# No location info found for Powderbird
# No lift info found for Powderbird
# 516 / 531 complete: Powderbird
# Price tag not found for Yukon Alpine Heliskiing.
# No elevation info found for Yukon Alpine Heliskiing
# No slope length info found for Yukon Alpine Heliskiing
# No location info found for Yukon Alpine Heliskiing
# No lift info found for Yukon Alpine Heliskiing
# 517 / 531 complete: Yukon Alpine Heliskiing
# Price tag not found for Whisper Ridge  (temporarily closed).
# No elevation info found for Whisper Ridge  (temporarily closed)
# No slope length info found for Whisper Ridge  (temporarily closed)
# No location info found for Whisper Ridge  (temporarily closed)
# No lift info found for Whisper Ridge  (temporarily closed)
# 518 / 531 complete: Whisper Ridge  (temporarily closed)
# Price tag not found for H2O Guides.
# No elevation info found for H2O Guides
# No slope length info found for H2O Guides
# No location info found for H2O Guides
# No lift info found for H2O Guides
# 519 / 531 complete: H2O Guides
# Price tag not found for Diamond Peaks.
# No elevation info found for Diamond Peaks
# No slope length info found for Diamond Peaks
# No location info found for Diamond Peaks
# No lift info found for Diamond Peaks
# 520 / 531 complete: Diamond Peaks
# Price tag not found for Scotch Valley Resort  (temporarily closed).
# No elevation info found for Scotch Valley Resort  (temporarily closed)
# No slope length info found for Scotch Valley Resort  (temporarily closed)
# No location info found for Scotch Valley Resort  (temporarily closed)
# No lift info found for Scotch Valley Resort  (temporarily closed)
# 521 / 531 complete: Scotch Valley Resort  (temporarily closed)
# Price tag not found for Lynx Creek.
# No elevation info found for Lynx Creek
# No slope length info found for Lynx Creek
# No location info found for Lynx Creek
# No lift info found for Lynx Creek
# 522 / 531 complete: Lynx Creek
# Price tag not found for Riverside Hills.
# No elevation info found for Riverside Hills
# No slope length info found for Riverside Hills
# No location info found for Riverside Hills
# No lift info found for Riverside Hills
# 523 / 531 complete: Riverside Hills
# Price tag not found for Las Vegas Wet (planned) (indoor ski area).
# No elevation info found for Las Vegas Wet (planned) (indoor ski area)
# No slope length info found for Las Vegas Wet (planned) (indoor ski area)
# No location info found for Las Vegas Wet (planned) (indoor ski area)
# No lift info found for Las Vegas Wet (planned) (indoor ski area)
# 524 / 531 complete: Las Vegas Wet (planned) (indoor ski area)
# Price tag not found for Sunset Ski Area.
# No elevation info found for Sunset Ski Area
# No slope length info found for Sunset Ski Area
# No location info found for Sunset Ski Area
# No lift info found for Sunset Ski Area
# 525 / 531 complete: Sunset Ski Area
# Price tag not found for Quadna Mountain.
# No elevation info found for Quadna Mountain
# No slope length info found for Quadna Mountain
# No location info found for Quadna Mountain
# No lift info found for Quadna Mountain
# 526 / 531 complete: Quadna Mountain
# Price tag not found for Mott Mountain.
# No elevation info found for Mott Mountain
# No slope length info found for Mott Mountain
# No location info found for Mott Mountain
# No lift info found for Mott Mountain
# 527 / 531 complete: Mott Mountain
# Price tag not found for Carson Ski Resort.
# No elevation info found for Carson Ski Resort
# No slope length info found for Carson Ski Resort
# No location info found for Carson Ski Resort
# No lift info found for Carson Ski Resort
# 528 / 531 complete: Carson Ski Resort
# Price tag not found for North Bicentennial Park  (temporarily closed).
# No elevation info found for North Bicentennial Park  (temporarily closed)
# No slope length info found for North Bicentennial Park  (temporarily closed)
# No location info found for North Bicentennial Park  (temporarily closed)
# No lift info found for North Bicentennial Park  (temporarily closed)
# 529 / 531 complete: North Bicentennial Park  (temporarily closed)
# Price tag not found for Huntington.
# No elevation info found for Huntington
# No slope length info found for Huntington
# No location info found for Huntington
# No lift info found for Huntington
# 530 / 531 complete: Huntington
# Price tag not found for Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area).
# No elevation info found for Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area)
# No slope length info found for Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area)
# No location info found for Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area)
# No lift info found for Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area)
# 531 / 531 complete: Bearfire Resort – Dallas-Fort Worth (planned) (indoor ski area)

# %% [markdown]
# ### Converting to DataFrame for easy viewing and manipulation

# %%
import pandas as pd

resorts_df = pd.DataFrame(resorts)
resorts_df
# Out:
#                                                   name  \
# 0                                       Big Sky Resort
# 1                                                 Vail
# 2                                            Telluride
# 3                                             Snowmass
# 4                                     Mammoth Mountain
# ..                                                 ...
# 526                                      Mott Mountain
# 527                                  Carson Ski Resort
# 528      North Bicentennial Park  (temporarily closed)
# 529                                         Huntington
# 530  Bearfire Resort – Dallas-Fort Worth (planned) ...
#
#                                                    url  price  \
# 0    https://www.skiresort.info/ski-resort/big-sky-...  275.0
# 1          https://www.skiresort.info/ski-resort/vail/  329.0
# 2     https://www.skiresort.info/ski-resort/telluride/  260.0
# 3      https://www.skiresort.info/ski-resort/snowmass/  264.0
# 4    https://www.skiresort.info/ski-resort/mammoth-...  259.0
# ..                                                 ...    ...
# 526  https://www.skiresort.info/ski-resort/mott-mou...    NaN
# 527  https://www.skiresort.info/ski-resort/carson-s...    NaN
# 528  https://www.skiresort.info/ski-resort/north-bi...    NaN
# 529  https://www.skiresort.info/ski-resort/huntington/    NaN
# 530  https://www.skiresort.info/ski-resort/bearfire...    NaN
#
#      base_elevation_m  peak_elevation_m  vertical_drop_m  slope_km  \
# 0              2073.0            3403.0           1330.0     250.0
# 1              2457.0            3527.0           1070.0     234.0
# 2              2660.0            3815.0           1155.0      88.2
# 3              2473.0            3813.0           1340.0     237.0
# 4              2424.0            3369.0            945.0      89.8
# ..                ...               ...              ...       ...
# 526               NaN               NaN              NaN       NaN
# 527               NaN               NaN              NaN       NaN
# 528               NaN               NaN              NaN       NaN
# 529               NaN               NaN              NaN       NaN
# 530               NaN               NaN              NaN       NaN
#
#           state  num_lifts
# 0       Montana       40.0
# 1      Colorado       34.0
# 2      Colorado       19.0
# 3      Colorado       20.0
# 4    California       25.0
# ..          ...        ...
# 526        None        NaN
# 527        None        NaN
# 528        None        NaN
# 529        None        NaN
# 530        None        NaN
#
# [531 rows x 9 columns]

# %% [markdown]
# ### Converting metric units to imperial (only because this is US-focused)

# %%
resorts_df = resorts_df.rename(columns={'base_elevation_m': 'base_elevation_ft', 'peak_elevation_m': 'peak_elevation_ft',
                           'vertical_drop_m': 'vertical_drop_ft', 'slope_km': 'slope_mi'})

# Convert meters to feet (1 m ≈ 3.28084 ft)
resorts_df['base_elevation_ft'] = (resorts_df['base_elevation_ft'] * 3.28084).round().astype('Int64')
resorts_df['peak_elevation_ft'] = (resorts_df['peak_elevation_ft'] * 3.28084).round().astype('Int64')
resorts_df['vertical_drop_ft'] = (resorts_df['vertical_drop_ft'] * 3.28084).round().astype('Int64')

# Convert kilometers to miles (1 km ≈ 0.621371 mi)
resorts_df['slope_mi'] = (resorts_df['slope_mi'] * 0.621371).round().astype('Int64')

# Get rid of decimal in num_lifts
resorts_df['num_lifts'] = resorts_df['num_lifts'].astype('Int64')

resorts_df
# Out:
#                                                   name  \
# 0                                       Big Sky Resort
# 1                                                 Vail
# 2                                            Telluride
# 3                                             Snowmass
# 4                                     Mammoth Mountain
# ..                                                 ...
# 526                                      Mott Mountain
# 527                                  Carson Ski Resort
# 528      North Bicentennial Park  (temporarily closed)
# 529                                         Huntington
# 530  Bearfire Resort – Dallas-Fort Worth (planned) ...
#
#                                                    url  price  \
# 0    https://www.skiresort.info/ski-resort/big-sky-...  275.0
# 1          https://www.skiresort.info/ski-resort/vail/  329.0
# 2     https://www.skiresort.info/ski-resort/telluride/  260.0
# 3      https://www.skiresort.info/ski-resort/snowmass/  264.0
# 4    https://www.skiresort.info/ski-resort/mammoth-...  259.0
# ..                                                 ...    ...
# 526  https://www.skiresort.info/ski-resort/mott-mou...    NaN
# 527  https://www.skiresort.info/ski-resort/carson-s...    NaN
# 528  https://www.skiresort.info/ski-resort/north-bi...    NaN
# 529  https://www.skiresort.info/ski-resort/huntington/    NaN
# 530  https://www.skiresort.info/ski-resort/bearfire...    NaN
#
#      base_elevation_ft  peak_elevation_ft  vertical_drop_ft  slope_mi  \
# 0                 6801              11165              4364       155
# 1                 8061              11572              3510       145
# 2                 8727              12516              3789        55
# 3                 8114              12510              4396       147
# 4                 7953              11053              3100        56
# ..                 ...                ...               ...       ...
# 526               <NA>               <NA>              <NA>      <NA>
# 527               <NA>               <NA>              <NA>      <NA>
# 528               <NA>               <NA>              <NA>      <NA>
# 529               <NA>               <NA>              <NA>      <NA>
# 530               <NA>               <NA>              <NA>      <NA>
#
#           state  num_lifts
# 0       Montana         40
# 1      Colorado         34
# 2      Colorado         19
# 3      Colorado         20
# 4    California         25
# ..          ...        ...
# 526        None       <NA>
# 527        None       <NA>
# 528        None       <NA>
# 529        None       <NA>
# 530        None       <NA>
#
# [531 rows x 9 columns]

# %% [markdown]
# ### Download DataFrame as CSV

# %%
resorts_df.to_csv('skiresort_dot_info.csv', index=False)

# %% [markdown]
# *NOTE: The csv downloaded here does not contain the final data for ski resorts. Using a regular spreadsheet editor, I manually changed several ski resort names to match them between the different sources (for example, "Brighton" was changed to "Brighton Mountain"). The final csv for the data from this source is called skiresort_dot_info_new.
